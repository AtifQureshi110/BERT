# %% [markdown]
# <a href="https://colab.research.google.com/github/AtifQureshi110/BERT/blob/main/text_generation_locked.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 48.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 24.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 63.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.7 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# %%
generator = pipeline("text-generation", model="distilgpt2")

# %%
generator = pipeline("text-generation", model="distilgpt2")
output = generator("AI and data science course we will teach you how to",
                   max_length=30,
                   num_return_sequences=3)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
output
# Out:
# [{'generated_text': 'AI and data science course we will teach you how to apply computational modeling and a methodological paradigm to data analytics.\n\n\n\n\nRelated Links'},
#  {'generated_text': 'AI and data science course we will teach you how to connect to you.'},
#  {'generated_text': 'AI and data science course we will teach you how to create a secure web-based website, or share a database with other data scientists who work with'}]

# %%
for info in output:
  for key ,value in info.items():
    print(value)
# Out:
# AI and data science course we will teach you how to apply computational modeling and a methodological paradigm to data analytics.
#
#
#
#
# Related Links
# AI and data science course we will teach you how to connect to you.
# AI and data science course we will teach you how to create a secure web-based website, or share a database with other data scientists who work with

# %%
import pandas as pd

data = {
    'Incomplete Sentence': [
        "AI and data science course we will teach you how to",
        "In the world of technology, artificial intelligence is",
        "Machine learning algorithms can help businesses make",
        "Natural language processing is a field of study that focuses on",
        "Big data analytics plays a crucial role in",
        "The future of robotics and automation looks promising with",
        "Deep learning models are used in various applications such as",
        "Blockchain technology is revolutionizing industries by",
        "Cybersecurity is essential for protecting sensitive",
        "The Internet of Things (IoT) connects devices and",
        "Quantum computing has the potential to solve complex problems",
        "Data privacy and ethics are important considerations in"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                                   Incomplete Sentence
# 0   AI and data science course we will teach you h...
# 1   In the world of technology, artificial intelli...
# 2   Machine learning algorithms can help businesse...
# 3   Natural language processing is a field of stud...
# 4          Big data analytics plays a crucial role in
# 5   The future of robotics and automation looks pr...
# 6   Deep learning models are used in various appli...
# 7   Blockchain technology is revolutionizing indus...
# 8   Cybersecurity is essential for protecting sens...
# 9   The Internet of Things (IoT) connects devices and
# 10  Quantum computing has the potential to solve c...
# 11  Data privacy and ethics are important consider...

# %%
output_list = []
for i in df['Incomplete Sentence']:
  output = generator(i, max_length=30, num_return_sequences=1)
  output_list.append(output[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
output_list
# Out:
# ['AI and data science course we will teach you how to implement data science across schools, universities and communities by applying new skills as needed.\n\n\n',
#  "In the world of technology, artificial intelligence is something that's going on, and it's a big industry for us. The next big question is,",
#  'Machine learning algorithms can help businesses make an economic sense for them. At an annual TEDx event in San Francisco, an economist named William Eisner argues',
#  'Natural language processing is a field of study that focuses on the social, cultural, and demographic effects of processing, e.g., how the data is',
#  "Big data analytics plays a crucial role in the analytics game, as its main part of the process. Here's some more insight.\n\n\n\n",
#  "The future of robotics and automation looks promising with the ability to revolutionise production. We‼️\n\n\n\nWe've made these statements by",
# ...

# %%
df['Complete Sentences'] = output_list

# %%
df
# Out:
#                                   Incomplete Sentence  \
# 0   AI and data science course we will teach you h...
# 1   In the world of technology, artificial intelli...
# 2   Machine learning algorithms can help businesse...
# 3   Natural language processing is a field of stud...
# 4          Big data analytics plays a crucial role in
# 5   The future of robotics and automation looks pr...
# 6   Deep learning models are used in various appli...
# 7   Blockchain technology is revolutionizing indus...
# 8   Cybersecurity is essential for protecting sens...
# 9   The Internet of Things (IoT) connects devices and
# 10  Quantum computing has the potential to solve c...
# 11  Data privacy and ethics are important consider...
#
#                                    Complete Sentences
# 0   AI and data science course we will teach you h...
# 1   In the world of technology, artificial intelli...
# 2   Machine learning algorithms can help businesse...
# ...
